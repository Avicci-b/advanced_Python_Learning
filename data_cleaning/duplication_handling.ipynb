# %%
import pandas as pd

# %%
df=pd.read_csv("../data/raw/duplicates_scenario.csv")
print("Successfully read the csv file")
# Out:
# Successfully read the csv file

# %%
df.head()
# Out:
#    ID  Name  GPA         Email
# 0   1  John  3.5  ad@gmail.com
# 1   2  Sara  3.9  df@gmail.com
# 2   2  Sara  3.9  ad@gmail.com
# 3   1  John  3.5  ad@gmail.com

# %%
df.shape
# Out:
# (4, 4)

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    ID  Name  GPA         Email
# 3   1  John  3.5  ad@gmail.com

# %%
df.duplicated(subset=["Email"])

df.drop_duplicates(subset=["Email"])
# Out:
#    ID  Name  GPA         Email
# 0   1  John  3.5  ad@gmail.com
# 1   2  Sara  3.9  df@gmail.com

# %%
df.drop_duplicates(keep="last",inplace=True)
#df[df.duplicated()]

df
# Out:
#    ID  Name  GPA
# 0   1  John  3.5
# 1   2  Sara  3.9
