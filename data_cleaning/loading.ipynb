# %% [markdown]
# ## Import dependecies

# %%
import pandas as pd

# %% [markdown]
# ## Loading the JSON file

# %%
print("Imported pandas successfully")

df=pd.read_json("../data/raw/students.json")
print("Imported json file")
#df.head()
#df.info()
df.describe()
# Out:
# Imported pandas successfully
# Imported json file
#              age
# count   2.000000
# mean   20.500000
# std     0.707107
# min    20.000000
# 25%    20.250000
# 50%    20.500000
# 75%    20.750000
# max    21.000000

# %% [markdown]
# ## Loading the CSV file

# %%
dfs=pd.read_csv("../data/raw/student.csv")
print("Sucess!!")

#dfs.head()

#dfs.tail()

#dfs.info()

#dfs.dtypes

#dfs.describe()

#df.shape

#df["name"].dtypes

#using astype() method to change data types
df["name"]=df["name"].astype(str)

#using to_numeric()
pd.to_numeric(df["age"],errors="coerce")
# Out:
# Sucess!!
# 0    21
# 1    20
# Name: age, dtype: int64
